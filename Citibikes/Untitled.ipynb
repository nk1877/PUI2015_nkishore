# %%
import pylab as pl
import pandas as pd
import subprocess
import sys

import numpy as np
# %pylab inline

import os
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
HOST="shell.cusp.nyu.edu"

# %%
COMMAND="uname -a"

# %%
df=pd.read_csv('https://data.cityofnewyork.us/OData.svc/825b-niea')

# %%
df
# Out:
#                  <?xml version='1.0' encoding='UTF-8'?>
# 0     <feed xmlns="http://www.w3.org/2005/Atom" xml:...
# 1                                               <entry>
# 2     <id>https://data.cityofnewyork.us/OData.svc/82...
# 3                 <d:__id m:type="Edm.Int64">1</d:__id>
# 4                                  <d:grade>3</d:grade>
# 5                                 <d:year>2006</d:year>
# 6                        <d:category>Asian</d:category>
# 7     <d:number_tested m:type="Edm.Decimal">9768</d:...
# 8     <d:mean_scale_score m:type="Edm.Decimal">700</...
# 9     <d:level_1_1 m:type="Edm.Decimal">243</d:level...
# 10    <d:level_1_2 m:type="Edm.Decimal">0.025</d:lev...
# 11    <d:level_2_1 m:type="Edm.Decimal">543</d:level...
# 12    <d:level_2_2 m:type="Edm.Decimal">0.056</d:lev...
# 13    <d:level_3_1 m:type="Edm.Decimal">4128</d:leve...
# 14    <d:level_3_2 m:type="Edm.Decimal">0.423</d:lev...
# 15    <d:level_4_1 m:type="Edm.Decimal">4854</d:leve...
# ...
